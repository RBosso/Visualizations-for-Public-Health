# %%
#COVID Correlations
#Import Libraries Used
#The Datasets used are from:

# Hannah Ritchie, Edouard Mathieu, Lucas Rodés-Guirao, Cameron Appel, Charlie Giattino, 
# Esteban Ortiz-Ospina, Joe Hasell, Bobbie Macdonald, Diana Beltekian and Max Roser (2020) 
# - "Coronavirus Pandemic (COVID-19)". Published online at OurWorldInData.org. 
# Retrieved from: 'https://ourworldindata.org/coronavirus' [Online Resource]

import os
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

plt.style.use('ggplot')

from matplotlib.pyplot import figure

# %matplotlib inline 

#Reads from the dataset
df = pd.read_csv(r'/content/sample_data/diabetes_and_Mortality.csv')
df.head() #Top of the dataset
# Out:
#             Nations  diabetes_prevalence  COVID_Mortality_Rate
# 0     New Caledonia                23.36              0.478542
# 1          Kiribati                22.66              0.401731
# 2  French Polynesia                22.63              0.883582
# 3         Mauritius                22.02              0.434564
# 4   Solomon Islands                18.68              0.710175

# %%
plt.scatter(x = df['diabetes_prevalence'], y = df['COVID_Mortality_Rate'])
plt.title('Diabetes Prevalence vs. COVID Mortality Rate')
plt.xlabel('Diabetes Prevalence')
plt.ylabel('COVID Mortality Rate')
plt.show()
df.corr()
# Out:
#                       diabetes_prevalence  COVID_Mortality_Rate
# diabetes_prevalence              1.000000             -0.094689
# COVID_Mortality_Rate            -0.094689              1.000000

# %%
#Overall, when considering COVID mortality rates across multiple countries,
#there seems to be a poor correlation between mortality rates and diabetes prevalence.

# %%
#Reads from the dataset
df = pd.read_csv(r'/content/sample_data/diabetes_and_GDP.csv')
df.head() #Top of the dataset
# Out:
#      location  gdp_per_capita  diabetes_prevalence
# 0       Qatar      116935.600                16.52
# 1  Luxembourg       94277.965                 4.42
# 2   Singapore       85535.383                10.99
# 3      Brunei       71809.251                12.79
# 4     Ireland       67335.293                 3.28

# %%
plt.scatter(x = df['diabetes_prevalence'], y = df['gdp_per_capita'])
plt.title('Diabetes Prevalence vs. GDP Per Capita')
plt.xlabel('Diabetes Prevalence')
plt.ylabel('GDP Per Capita')
plt.show()
df.corr()
#There seems to be a relatively poor correlation between diabetes prevalence and GDP Per Capita
# Out:
#                      gdp_per_capita  diabetes_prevalence
# gdp_per_capita             1.000000             0.124237
# diabetes_prevalence        0.124237             1.000000

# %%
#Reads from the dataset
df = pd.read_csv(r'/content/sample_data/GDP_and_Mortality.csv')
df.head() #Top of the dataset
# Out:
#       Nations  gdp_per_capita  COVID_Mortality_Rate
# 0       Qatar      116935.600              0.175666
# 1       Macao      104861.851              0.433839
# 2  Luxembourg       94277.965              0.408656
# 3   Singapore       85535.383              0.095123
# 4      Brunei       71809.251              0.132471

# %%
plt.scatter(x = df['gdp_per_capita'], y = df['COVID_Mortality_Rate'])
plt.title('GDP vs. COVID Mortality Rate')
plt.xlabel('GDP Per Capita')
plt.ylabel('COVID Mortality Rate')
plt.show()

# %%
sns.regplot(x = 'gdp_per_capita', y='COVID_Mortality_Rate', data = df, scatter_kws = {"color" : "red"}, line_kws = {"color" : "blue"})
df.corr()
# Out:
#                       gdp_per_capita  COVID_Mortality_Rate
# gdp_per_capita              1.000000             -0.316622
# COVID_Mortality_Rate       -0.316622              1.000000

# %%
matrix = df.corr(method = "spearman") #Monotonic
sns.heatmap(matrix, annot = True)
plt.title("Correlation Matrix for Features Using Spearman Method")
plt.show()
print()
matrix = df.corr(method = "pearson") #Linear
sns.heatmap(matrix, annot = True)
plt.title("Correlation Matrix for Features Using Pearson Method")
plt.show()

# %%
#There does seem to be some correlation between GDP Per Capita and COVID Mortality Rates.

# %%
#Reads from the dataset
df = pd.read_csv(r'/content/human_development_index_and_Mortality.csv')
df.head() #Top of the dataset
# Out:
#        Nations  human_development_index  COVID_Mortality_Rate
# 0       Norway                    0.957              0.235576
# 1      Ireland                    0.955              0.466732
# 2  Switzerland                    0.955              0.363684
# 3    Hong Kong                    0.949              0.747045
# 4      Iceland                    0.949              0.091082

# %%
plt.scatter(x = df['human_development_index'], y = df['COVID_Mortality_Rate'])
plt.title('Human Development Index vs. COVID Mortality Rate')
plt.xlabel('Human Development')
plt.ylabel('COVID Mortality Rate')
plt.show()

# %%
sns.regplot(x = 'human_development_index', y='COVID_Mortality_Rate', data = df, scatter_kws = {"color" : "red"}, line_kws = {"color" : "blue"})
df.corr()
# Out:
#                          human_development_index  COVID_Mortality_Rate
# human_development_index                 1.000000             -0.344158
# COVID_Mortality_Rate                   -0.344158              1.000000

# %%
matrix = df.corr(method = "spearman") #Monotonic
sns.heatmap(matrix, annot = True)
plt.title("Correlation Matrix for Features Using Spearman Method")
plt.show()
print()
matrix = df.corr(method = "pearson") #Linear
sns.heatmap(matrix, annot = True)
plt.title("Correlation Matrix for Features Using Pearson Method")
plt.show()

# %%
# Human Development Index and GDP Per Capita share relatively similar
# correlations to COVID mortality rates.

# %%
#Reads from the dataset
df = pd.read_csv(r'/content/sample_data/human_development_index_and_GDP.csv')
df.head() #Top of the dataset
# Out:
#      location  gdp_per_capita  human_development_index
# 0       Qatar      116935.600                    0.848
# 1  Luxembourg       94277.965                    0.916
# 2   Singapore       85535.383                    0.938
# 3      Brunei       71809.251                    0.838
# 4     Ireland       67335.293                    0.955

# %%
plt.scatter(x = df['human_development_index'], y = df['gdp_per_capita'])
plt.title('Human Development Index vs. GDP')
plt.xlabel('Human Development')
plt.ylabel('GDP Per Capita')
plt.show()

# %%
sns.regplot(x = 'human_development_index', y='gdp_per_capita', data = df, scatter_kws = {"color" : "red"}, line_kws = {"color" : "blue"}, order = 2)
df.corr()
#A second - order polynomial regression fits this data very well
# Out:
#                          gdp_per_capita  human_development_index
# gdp_per_capita                 1.000000                 0.753171
# human_development_index        0.753171                 1.000000

# %%
matrix = df.corr(method = "spearman") #Monotonic
sns.heatmap(matrix, annot = True)
plt.title("Correlation Matrix for Features Using Spearman Method")
plt.show()
print()
matrix = df.corr(method = "pearson") #Linear
sns.heatmap(matrix, annot = True)
plt.title("Correlation Matrix for Features Using Pearson Method")
plt.show()

# %%
# In addition to the fact that there is a strong linear correlation between GDP and Human Development Index,
# there is an even stronger correlation indicated by the Spearman Method, suggesting that the relation
# between GDP Per Capita and the Human Development Index is more effectively modeled by a nonlinear function.

# %%
#Reads from the dataset
df = pd.read_csv(r'/content/sample_data/full_vac_and_Mortality.csv')
df.head() #Top of the dataset
# Out:
#                 Nations  Percent_Fully_Vaccinated  COVID_Mortality_Rate
# 0             Gibraltar                122.943813              0.570428
# 1                 Samoa                 99.003218              0.193910
# 2  United Arab Emirates                 98.010056              0.248153
# 3                Brunei                 96.655282              0.151015
# 4             Singapore                 91.647151              0.096322

# %%
sns.regplot(x = 'Percent_Fully_Vaccinated', y='COVID_Mortality_Rate', data = df, scatter_kws = {"color" : "red"}, line_kws = {"color" : "blue"})
#sns.regplot(x = 'Percent_Fully_Vaccinated', y='COVID_Mortality_Rate', data = df, scatter_kws = {"color" : "red"}, line_kws = {"color" : "blue"}).set_yscale('log')
df.corr()
# Out:
#                           Percent_Fully_Vaccinated  COVID_Mortality_Rate
# Percent_Fully_Vaccinated                   1.00000              -0.40442
# COVID_Mortality_Rate                      -0.40442               1.00000

# %%
matrix = df.corr(method = "spearman") #Monotonic
sns.heatmap(matrix, annot = True)
plt.title("Correlation Matrix for Features Using Spearman Method")
plt.show()
print()
matrix = df.corr(method = "pearson") #Linear
sns.heatmap(matrix, annot = True)
plt.title("Correlation Matrix for Features Using Pearson Method")
plt.show()

# %%
#Particularly as indicated by a Spearman correlation value of -0.56,
#there seems to be a relatively strong correlation between rates of
#full vaccinations and COVID Mortality Rates
